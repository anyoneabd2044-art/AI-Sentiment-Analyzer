# %% [markdown]
# <a href="https://colab.research.google.com/github/anyoneabd2044-art/AI-Sentiment-Analyzer/blob/main/AI_Based_Sentiment_AnalyzerPhase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch matplotlib

# %%
from transformers import pipeline
import matplotlib.pyplot as plt

# Load sentiment analysis model
sentiment_pipeline = pipeline("sentiment-analysis")

def analyze_sentiment(text):
    result = sentiment_pipeline(text)[0]
    label = result['label']
    score = result['score']

    print("Text:", text)
    print("Sentiment:", label)
    print("Confidence Score:", round(score, 3))

    # Visualization
    plt.figure()
    plt.bar(label, score)
    plt.ylim(0, 1)
    plt.xlabel("Sentiment")
    plt.ylabel("Confidence Score")
    plt.title("Sentiment Analysis Result")
    plt.show()

# Example
text_input = input("Enter text to analyze sentiment: ")
analyze_sentiment(text_input)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# Enter text to analyze sentiment: disgusting
# Text: disgusting
# Sentiment: NEGATIVE
# Confidence Score: 0.999
